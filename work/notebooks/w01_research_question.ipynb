# %% [markdown]
# <a href="https://colab.research.google.com/github/ArsanyRefaat/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ArsanyRefaat/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# My Lane

I chose the Content Refresh lane.

I am interested in identifying content that is losing search performance so that it can be reviewed before traffic drops further. This problem has a clear business value because content updates can improve visibility and user engagement.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Research Question

Decision:
Which content pages should be prioritized for review?

Action:
Review and update pages that are likely to lose organic traffic.

Cost of a wrong recommendation:
If a healthy page is selected, time is wasted. If a declining page is missed, search traffic and potential business value may decrease.

Why ML can help:
The dataset contains historical search performance metrics that may reveal patterns associated with declining content.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Dataset shape:", df.shape)

print("\nTrend Direction:")
print(df["trend_direction"].value_counts())

print("\nTop Content Types:")
print(df["content_type"].value_counts().head())
### 3. Quick Look at the Data

The starter dataset contains **30,000 content items** and **44 features**.

From the `trend_direction` column:

- **16,262** pages are trending **down**.
- **5,962** pages are **stable**.
- **4,388** pages are trending **up**.

#The most common content type is **keyword article** with **27,207** pages, followed by **feedly article** (2,096 pages) and **comparison article** (697 pages).

#These observations suggest that there are many pages showing declining performance, making the Content Refresh lane a meaningful decision-support problem to investigate over the next seven weeks.
# Out:
# Dataset shape: (30000, 44)
#
# Trend Direction:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Top Content Types:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## 4. Careful Words

The findings from this project will be observational and directional. They are intended to support content review decisions based on historical search performance.

This work cannot prove causal relationships or predict Google's ranking algorithm. Any recommendations should be treated as decision support rather than definitive conclusions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x ] Every section above is filled — markdown thinking AND the code that backs it
# - [ x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ x] No client names, URLs, or private queries anywhere
# - [x ] My claims use careful words: observed, measured, directional, decision-support
# - [ x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
